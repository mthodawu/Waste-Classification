# %%
# %pip install scikit-learn
# %pip install tensorflow
# %pip install seaborn matplotlib pandas

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import os
from tensorflow.keras.backend import clear_session
from sklearn.model_selection import train_test_split
import shutil
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Dense, Flatten
from tensorflow.keras.models import load_model
from tensorflow.keras import mixed_precision
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import confusion_matrix, precision_score, recall_score, average_precision_score

# Enable mixed precision training
mixed_precision.set_global_policy('mixed_float16')

import warnings
warnings.filterwarnings('ignore')

clear_session()  # This frees the GPU memory, peventing training deadlock


# Function to create directories
def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)
        
setz = ['metal','glass', 'trash', 'cardboard', 'paper', 'plastic']

# for setClass in [setz[2]]: #setz:
# clear_session()
global classez
classez = setz #[setClass, 'other']
# data path
global dataset_path
# dataset_path = f'/app/data/Datasets/augmented_{classez[0]}_and_{classez[1]}'  # <- docker file path      # "G:\My Drive\Datasets\ "
dataset_path = f'/app/data/Datasets/Trashnet-resized'  # <- docker file path      # "G:\My Drive\Datasets\ "

tar = (128, 128)#(224, 224)
batch = 8 # 16
#Split the dataset
# Create an ImageDataGenerator for each subset
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.13)  # 20% for validation

# Training data generator
train_generator = datagen.flow_from_directory(
    dataset_path,
    target_size=tar,
    batch_size=batch,
    class_mode='categorical',
    subset='training')  # Set as training data

# Validation data generator
validation_generator = datagen.flow_from_directory(
    dataset_path,
    target_size=tar,
    batch_size=batch,
    class_mode='categorical',
    subset='validation')  # Set as validation data

# Create a separate ImageDataGenerator for test data
test_datagen = ImageDataGenerator(rescale=1./255)

# Test data generator
test_generator = test_datagen.flow_from_directory(
    dataset_path,
    target_size=tar,
    batch_size=batch,
    class_mode='categorical')  # No subset for testing



# Paths to save splits
base_dir = f'{dataset_path}-split'  # "G:\My Drive\Datasets\Trashnet-resized-split"
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')

create_dir(base_dir)
create_dir(train_dir)
create_dir(val_dir)
create_dir(test_dir)

for class_name in classez: #, 'cardboard', 'metal', 'paper', 'plastic', 'trash']:
    # Create class directories
    create_dir(os.path.join(train_dir, class_name))
    create_dir(os.path.join(val_dir, class_name))
    create_dir(os.path.join(test_dir, class_name))

    # List all files in the class directory
    class_files = os.listdir(os.path.join(dataset_path, class_name))
    train_files, test_files = train_test_split(class_files, test_size=0.2, random_state=42)  # 20% for testing
    train_files, val_files = train_test_split(train_files, test_size=0.25, random_state=42)  # 20% of remaining for validation (0.25 * 0.8 = 0.2)

    # Copy files to respective directories
    for file in train_files:
        shutil.copy(os.path.join(dataset_path, class_name, file), os.path.join(train_dir, class_name, file))

    for file in val_files:
        shutil.copy(os.path.join(dataset_path, class_name, file), os.path.join(val_dir, class_name, file))

    for file in test_files:
        shutil.copy(os.path.join(dataset_path, class_name, file), os.path.join(test_dir, class_name, file))
    
train_generator = datagen.flow_from_directory(
train_dir,
target_size=tar,
batch_size=batch,
class_mode='categorical'
# ,color_mode='grayscale'
)

validation_generator = datagen.flow_from_directory(
    val_dir,
    target_size=tar,
    batch_size=batch,
    class_mode='categorical'
    # ,color_mode='grayscale'
    )

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=tar,
    batch_size=batch,
    class_mode='categorical'
    # ,color_mode='grayscale'
    )

img_shape = (128, 128, 3) #(224,224,3)
img_size = tar
batch_size = batch #16 #32
num_classes = 6
log_file = '/app/data/code/accuracy_logMulti_1.csv'

class AccuracyLogger(Callback):
    def __init__(self,   log_file, model_name, img_shape, batch_size, num_classes):
        super().__init__()
        self.log_file = log_file
        self.model_name = model_name
        self.img_shape = img_shape
        self.batch_size = batch_size
        self.num_classes = num_classes
        
        # self.summary = summary

        # Write model and dataset information at the beginning of the log file
        with open(self.log_file, 'a') as f:
            f.write(f"\nModel: {self.model_name}\n")
            # f.write(f"Model summary:{self.summary}\n")
            f.write(f"Image shape: {self.img_shape}\n")
            f.write(f"Batch size: {self.batch_size}\n")
            f.write(f"Dataset: {dataset_path}\n")
            f.write(f"Number of classes: {self.num_classes}\n\n")
            f.write('Epoch,Accuracy,Validation Accuracy, Loss, Validation Loss\n')
            f.flush()

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        accuracy = logs.get('accuracy')
        val_accuracy = logs.get('val_accuracy')
        loss = logs.get('loss')
        val_loss = logs.get('val_loss')

        # Write the epoch, accuracy, and validation accuracy to the log file
        with open(self.log_file, 'a') as f:
            f.write(f"{epoch + 1},{accuracy},{val_accuracy},{loss},{val_loss}\n")
            f.flush()
            
#Yang and Thung implementation
model_name = 'Yang and Thung\'s AlexNet'
model = tf.keras.Sequential([
    # Layer 1: Convolution with 96 filters, 11x11, stride 4, padding 2
    tf.keras.layers.Conv2D(96, (11, 11), strides=4, padding='same', activation='relu', input_shape=(128, 128, 3)),
    
    # Layer 2: Max-Pooling with 3x3 filter, stride 2
    tf.keras.layers.MaxPooling2D(pool_size=(3, 3), strides=2),
    
    # Layer 3: Convolution with 192 filters, 5x5, stride 1, padding 2
    tf.keras.layers.Conv2D(192, (6, 6), strides=1, padding='same', activation='relu'),
    
    # Layer 4: Max-Pooling with 3x3 filter, stride 2
    tf.keras.layers.MaxPooling2D(pool_size=(3, 3), strides=2),
    
    # Layer 5: Convolution with 288 filters, 3x3, stride 1, padding 1
    tf.keras.layers.Conv2D(288, (3, 3), strides=1, padding='same', activation='relu'),
    
    # Layer 6: Convolution with 288 filters, 3x3, stride 1, padding 1
    tf.keras.layers.Conv2D(288, (3, 3), strides=1, padding='same', activation='relu'),
    
    # Layer 7: Convolution with 192 filters, 3x3, stride 1, padding 1
    tf.keras.layers.Conv2D(192, (3, 3), strides=1, padding='same', activation='relu'),
    
    # Layer 8: Max-Pooling with 3x3 filter, stride 2
    tf.keras.layers.MaxPooling2D(pool_size=(3, 3), strides=2),
    
    # Flatten the output
    tf.keras.layers.Flatten(),
    
    # Layer 9: Fully Connected with 4096 neurons
    tf.keras.layers.Dense(2048, activation='relu'),
    
    # Layer 10: Fully Connected with 4096 neurons
    tf.keras.layers.Dense(2048, activation='relu'),
    
    # Layer 11: Fully Connected with 5 neurons (output layer)
    tf.keras.layers.Dense(num_classes, activation='softmax')
])

lr_reduction = ReduceLROnPlateau(monitor='val_loss', 
                                patience=2, 
                                factor=0.3, #0.5,
                                verbose=1, 
                                min_lr=0.001) #0.01)

model.compile(optimizer = 'sgd',
            loss = 'categorical_crossentropy',
            metrics = ['accuracy'])

#Train for N epochs
steps_per_epoch=int(len(train_generator)/batch_size)
validation_steps = validation_generator.samples // validation_generator.batch_size

checkpoints = tf.keras.callbacks.ModelCheckpoint(
    filepath="/app/data/tf_model_YangandThung.keras",
    monitor="val_loss",
    verbose=0,
    save_best_only=True,
    save_weights_only=False,
    mode="auto",
    save_freq="epoch",
    initial_value_threshold=None,
)

history = model.fit(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    validation_data=validation_generator,
    callbacks=[AccuracyLogger(  log_file, model_name, img_shape, batch_size, num_classes),
                EarlyStopping(patience=5), checkpoints, lr_reduction],
    epochs=100,
    verbose=1
)

def plot_graphs(history, batch_size):
    fig, axs = plt.subplots(1, 2, figsize=(12, 5))  # 1 row, 2 columns

    # Plot accuracy
    axs[0].plot(history.history['accuracy'])
    axs[0].plot(history.history['val_accuracy'])
    axs[0].set_title("Model Accuracy")
    axs[0].set_xlabel("Epochs")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(['Train', 'Validation'])

    # Plot loss
    axs[1].plot(history.history['loss'])
    axs[1].plot(history.history['val_loss'])
    axs[1].set_title("Model Loss")
    axs[1].set_xlabel("Epochs")
    axs[1].set_ylabel("Loss")
    axs[1].legend(['Train', 'Validation'])

    plt.tight_layout()  # Adjust layout to make sure plots don't overlap

    # Ensure the save directory exists
    save_dir = '/app/data/graphs/'
    os.makedirs(save_dir, exist_ok=True)

    # Create the filename using the dataset path and batch size
    dataset_name = os.path.basename(dataset_path[29:])  # filter out '/app/data/Datasets/' 
    filename = f"{dataset_name}_30epoch_batch{batch_size}_{model_name}.png"

    # Save the figure
    save_path = os.path.join(save_dir, filename)
    plt.savefig(save_path)
    print(f"Graph saved at: {save_path}")

    plt.show()

# plot
plot_graphs(history, batch)

loss, accuracy = model.evaluate(test_generator, verbose=False)
print("Testing Accuracy:  {:.4f}".format(accuracy))
with open(log_file, 'a') as f:
    f.write(f"Testing Accuracy:  {accuracy:.4f}\n")
    f.flush()

# save model
model.save("/app/data/tf_model_YangandThung.keras")

print("Training complete!")
# Out:
# Found 2201 images belonging to 6 classes.
# Found 326 images belonging to 6 classes.
# Found 2527 images belonging to 6 classes.
# Found 1512 images belonging to 6 classes.
# Found 507 images belonging to 6 classes.
# Found 508 images belonging to 6 classes.
# Epoch 1/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.2734 - loss: 1.7543 - val_accuracy: 0.1972 - val_loss: 1.7434 - learning_rate: 0.0100
# Epoch 2/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.2485 - loss: 1.7285 - val_accuracy: 0.2347 - val_loss: 1.7280 - learning_rate: 0.0100
# Epoch 3/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.2308 - loss: 1.7359 - val_accuracy: 0.2742 - val_loss: 1.7175 - learning_rate: 0.0100
# Epoch 4/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.2926 - loss: 1.7163 - val_accuracy: 0.2347 - val_loss: 1.7025 - learning_rate: 0.0100
# Epoch 5/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 1.8446
# 2024-09-20 15:54:57.165851: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 4174635518040384029
# 2024-09-20 15:54:57.165883: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 6891314561632809628
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1237 - loss: 1.8984 - val_accuracy: 0.2347 - val_loss: 1.7278 - learning_rate: 0.0100
# Epoch 6/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.2547 - loss: 1.7332 - val_accuracy: 0.2761 - val_loss: 1.6917 - learning_rate: 0.0100
# Epoch 7/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.2055 - loss: 1.7503 - val_accuracy: 0.2919 - val_loss: 1.6808 - learning_rate: 0.0100
# Epoch 8/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.2450 - loss: 1.7329 - val_accuracy: 0.2347 - val_loss: 1.6918 - learning_rate: 0.0100
# Epoch 9/100
# 91/94 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2874 - loss: 1.6848
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0029999999329447745.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.2858 - loss: 1.6849 - val_accuracy: 0.3077 - val_loss: 1.6831 - learning_rate: 0.0100
# Epoch 10/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2500 - loss: 1.6797
# 2024-09-20 15:55:03.368866: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 4174635518040384029
# 2024-09-20 15:55:03.368893: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 6891314561632809628
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2500 - loss: 1.6476 - val_accuracy: 0.3136 - val_loss: 1.6626 - learning_rate: 0.0030
# Epoch 11/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.2826 - loss: 1.6551 - val_accuracy: 0.2347 - val_loss: 1.6589 - learning_rate: 0.0030
# Epoch 12/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.3106 - loss: 1.6397 - val_accuracy: 0.3905 - val_loss: 1.5911 - learning_rate: 0.0030
# Epoch 13/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.3226 - loss: 1.6295 - val_accuracy: 0.4162 - val_loss: 1.5471 - learning_rate: 0.0030
# Epoch 14/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.3242 - loss: 1.5641 - val_accuracy: 0.3274 - val_loss: 1.6118 - learning_rate: 0.0030
# Epoch 15/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5000 - loss: 1.3761
# 2024-09-20 15:55:09.891308: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 4174635518040384029
# 2024-09-20 15:55:09.891342: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 6891314561632809628
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.001.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5000 - loss: 1.4528 - val_accuracy: 0.3748 - val_loss: 1.5581 - learning_rate: 0.0030
# Epoch 16/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4452 - loss: 1.5252 - val_accuracy: 0.3767 - val_loss: 1.5577 - learning_rate: 0.0010
# Epoch 17/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.4251 - loss: 1.5660 - val_accuracy: 0.4043 - val_loss: 1.4913 - learning_rate: 0.0010
# Epoch 18/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.3944 - loss: 1.5019 - val_accuracy: 0.4103 - val_loss: 1.4885 - learning_rate: 0.0010
# Epoch 19/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.3929 - loss: 1.5619 - val_accuracy: 0.3925 - val_loss: 1.4940 - learning_rate: 0.0010
# Epoch 20/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7500 - loss: 0.9208
# 2024-09-20 15:55:16.160045: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 4174635518040384029
# 2024-09-20 15:55:16.160080: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 6891314561632809628
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3790 - loss: 1.3251 - val_accuracy: 0.4181 - val_loss: 1.4639 - learning_rate: 0.0010
# Epoch 21/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.3535 - loss: 1.4628 - val_accuracy: 0.4201 - val_loss: 1.4468 - learning_rate: 0.0010
# Epoch 22/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.3819 - loss: 1.4627 - val_accuracy: 0.3984 - val_loss: 1.4868 - learning_rate: 0.0010
# Epoch 23/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4486 - loss: 1.3927 - val_accuracy: 0.4201 - val_loss: 1.4828 - learning_rate: 0.0010
# Epoch 24/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.3927 - loss: 1.4761 - val_accuracy: 0.4103 - val_loss: 1.4735 - learning_rate: 0.0010
# Epoch 25/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7500 - loss: 1.0770
# 2024-09-20 15:55:22.405753: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 4174635518040384029
# 2024-09-20 15:55:22.405788: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 6891314561632809628
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5027 - loss: 1.5215 - val_accuracy: 0.4280 - val_loss: 1.4535 - learning_rate: 0.0010
# Epoch 26/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.3609 - loss: 1.5665 - val_accuracy: 0.4280 - val_loss: 1.4274 - learning_rate: 0.0010
# Epoch 27/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.4184 - loss: 1.4309 - val_accuracy: 0.4201 - val_loss: 1.4108 - learning_rate: 0.0010
# Epoch 28/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4162 - loss: 1.4829 - val_accuracy: 0.4221 - val_loss: 1.4464 - learning_rate: 0.0010
# Epoch 29/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4175 - loss: 1.4723 - val_accuracy: 0.4181 - val_loss: 1.4385 - learning_rate: 0.0010
# Epoch 30/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5000 - loss: 1.0485
# 2024-09-20 15:55:28.669990: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 4174635518040384029
# 2024-09-20 15:55:28.670025: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 6891314561632809628
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3763 - loss: 1.3677 - val_accuracy: 0.4359 - val_loss: 1.3908 - learning_rate: 0.0010
# Epoch 31/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.3780 - loss: 1.5225 - val_accuracy: 0.3984 - val_loss: 1.4844 - learning_rate: 0.0010
# Epoch 32/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.4800 - loss: 1.3381 - val_accuracy: 0.4497 - val_loss: 1.3853 - learning_rate: 0.0010
# Epoch 33/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.3994 - loss: 1.3563 - val_accuracy: 0.4260 - val_loss: 1.3728 - learning_rate: 0.0010
# Epoch 34/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4289 - loss: 1.4837 - val_accuracy: 0.4458 - val_loss: 1.4064 - learning_rate: 0.0010
# Epoch 35/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5000 - loss: 1.2997
# 2024-09-20 15:55:35.075856: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 	 [[IteratorGetNext/_2]]
# 2024-09-20 15:55:35.075887: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 4174635518040384029
# 2024-09-20 15:55:35.075897: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 6891314561632809628
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6237 - loss: 1.1815 - val_accuracy: 0.4379 - val_loss: 1.4126 - learning_rate: 0.0010
# Epoch 36/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.4063 - loss: 1.4541 - val_accuracy: 0.4635 - val_loss: 1.3703 - learning_rate: 0.0010
# Epoch 37/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4701 - loss: 1.3310 - val_accuracy: 0.3925 - val_loss: 1.4508 - learning_rate: 0.0010
# Epoch 38/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4693 - loss: 1.4368 - val_accuracy: 0.4497 - val_loss: 1.3747 - learning_rate: 0.0010
# Epoch 39/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4697 - loss: 1.3609 - val_accuracy: 0.4615 - val_loss: 1.3732 - learning_rate: 0.0010
# Epoch 40/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7500 - loss: 0.8373
# 2024-09-20 15:55:41.170893: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 4174635518040384029
# 2024-09-20 15:55:41.170935: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 6891314561632809628
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5027 - loss: 1.3720 - val_accuracy: 0.4793 - val_loss: 1.3497 - learning_rate: 0.0010
# Epoch 41/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4893 - loss: 1.2844 - val_accuracy: 0.4734 - val_loss: 1.3545 - learning_rate: 0.0010
# Epoch 42/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.4452 - loss: 1.3487 - val_accuracy: 0.4162 - val_loss: 1.4270 - learning_rate: 0.0010
# Epoch 43/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4887 - loss: 1.3136 - val_accuracy: 0.4122 - val_loss: 1.5265 - learning_rate: 0.0010
# Epoch 44/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.4458 - loss: 1.3839 - val_accuracy: 0.4517 - val_loss: 1.3469 - learning_rate: 0.0010
# Epoch 45/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5000 - loss: 1.2579
# 2024-09-20 15:55:47.441906: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 4174635518040384029
# 2024-09-20 15:55:47.441937: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 6891314561632809628
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5000 - loss: 1.6668 - val_accuracy: 0.4517 - val_loss: 1.3747 - learning_rate: 0.0010
# Epoch 46/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.4044 - loss: 1.3937 - val_accuracy: 0.5207 - val_loss: 1.3303 - learning_rate: 0.0010
# Epoch 47/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.4611 - loss: 1.3728 - val_accuracy: 0.4931 - val_loss: 1.2994 - learning_rate: 0.0010
# Epoch 48/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.4386 - loss: 1.3511 - val_accuracy: 0.5148 - val_loss: 1.2744 - learning_rate: 0.0010
# Epoch 49/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5657 - loss: 1.2001 - val_accuracy: 0.4556 - val_loss: 1.3613 - learning_rate: 0.0010
# Epoch 50/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7500 - loss: 0.7545
# 2024-09-20 15:55:53.882411: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 4174635518040384029
# 2024-09-20 15:55:53.882444: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 6891314561632809628
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6263 - loss: 1.0283 - val_accuracy: 0.5128 - val_loss: 1.2780 - learning_rate: 0.0010
# Epoch 51/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.5013 - loss: 1.3302 - val_accuracy: 0.4872 - val_loss: 1.2733 - learning_rate: 0.0010
# Epoch 52/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.5106 - loss: 1.2712 - val_accuracy: 0.5049 - val_loss: 1.2606 - learning_rate: 0.0010
# Epoch 53/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4891 - loss: 1.3416 - val_accuracy: 0.4813 - val_loss: 1.2778 - learning_rate: 0.0010
# Epoch 54/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4933 - loss: 1.2637 - val_accuracy: 0.4793 - val_loss: 1.3437 - learning_rate: 0.0010
# Epoch 55/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2500 - loss: 1.4660
# 2024-09-20 15:56:00.176667: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 4174635518040384029
# 2024-09-20 15:56:00.176700: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 6891314561632809628
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3737 - loss: 1.1906 - val_accuracy: 0.4813 - val_loss: 1.3344 - learning_rate: 0.0010
# Epoch 56/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5702 - loss: 1.1868 - val_accuracy: 0.4872 - val_loss: 1.3379 - learning_rate: 0.0010
# Epoch 57/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5375 - loss: 1.2726 - val_accuracy: 0.5030 - val_loss: 1.2976 - learning_rate: 0.0010
# Graph saved at: /app/data/graphs/esized_30epoch_batch4_Yang and Thung's AlexNet.png
# Testing Accuracy:  0.4232
# Training complete!

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, average_precision_score
import seaborn as sns

# Evaluate model on test data and get predictions
y_true = test_generator.classes
y_pred = model.predict(test_generator)
y_pred_classes = np.argmax(y_pred, axis=1)

# Confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)

# Precision and Recall
precision = precision_score(y_true, y_pred_classes, average='macro')
recall = recall_score(y_true, y_pred_classes, average='macro')

# mAP score
mAP = average_precision_score(tf.keras.utils.to_categorical(y_true, num_classes=num_classes), y_pred, average="macro")

# Log Precision, Recall, and mAP
with open(log_file, 'a') as f:
    f.write(f"Precision: {precision:.4f}, Recall: {recall:.4f}, mAP: {mAP:.4f}\n")
    f.flush()

print(f"Precision: {precision:.4f}, Recall: {recall:.4f}, mAP: {mAP:.4f}")

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_generator.class_indices.keys(), 
            yticklabels=test_generator.class_indices.keys())
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# Save confusion matrix plot
save_dir = '/app/data/graphs/'
os.makedirs(save_dir, exist_ok=True)
filename = f"confusion_matrix_{model_name}.png"
plt.savefig(os.path.join(save_dir, filename))
print(f"Confusion matrix saved at: {os.path.join(save_dir, filename)}")
plt.show()
