# %%
import tensorflow as tf
print("GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# GPUs Available:  1

# %%
import tensorflow as tf
# from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Conv2D
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras import mixed_precision
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import precision_recall_fscore_support, confusion_matrix, average_precision_score
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
# from tensorflow.keras.mixed_precision import mixed_precision  
from tensorflow.keras.backend import clear_session 

# Enable mixed precision training
mixed_precision.set_global_policy('mixed_float16')
clear_session()

physical_devices = tf.config.list_physical_devices('GPU')
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# Dataset path
dataset_path = '/app/data/Datasets/Trashnet-resized'
dataset_name = os.path.basename(dataset_path[18:])
# Parameters
img_shape = (160, 160, 3)
batch_size = 2
num_classes = 6
epochz = 30

# Data generators
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train_generator = datagen.flow_from_directory(
    dataset_path,
    target_size=img_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

validation_generator = datagen.flow_from_directory(
    dataset_path,
    target_size=img_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)

test_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(
    dataset_path,
    target_size=img_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)

# Model
def create_model():
    base_model = tf.keras.applications.MobileNetV2(input_shape=img_shape, include_top=False, weights='imagenet')
    base_model.trainable = False
    model_name = base_model.name

    model = Sequential([
        base_model,
        # Conv2D(32, (3, 3), activation='relu', input_shape=img_shape),
        GlobalAveragePooling2D(),
        Dense(64, activation="relu"),
        Dense(num_classes, activation="softmax")
    ])
    return model, model_name

model, model_name = create_model()
# Compile model
optimizer = Adam(learning_rate=0.00001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Callbacks
lr_reduction = ReduceLROnPlateau(monitor='val_loss', patience=2, factor=0.5, verbose=1, min_lr=0.00001)
early_stopping = EarlyStopping(patience=5, restore_best_weights=True)

# Train model
try:
    history = model.fit(
        train_generator,
        steps_per_epoch=train_generator.samples // batch_size,
        validation_data=validation_generator,
        validation_steps=validation_generator.samples // batch_size,
        epochs=epochz,
        callbacks=[lr_reduction, early_stopping],
        verbose=1
    )   
except Exception as e:
    print(f"An error occurred during training: {str(e)}")
    # If an error occurs, try recreating and recompiling the model
    tf.keras.backend.clear_session()
    model = create_model()
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Try training again
    history = model.fit(
        train_generator,
        steps_per_epoch=train_generator.samples // batch_size,
        validation_data=validation_generator,
        validation_steps=validation_generator.samples // batch_size,
        epochs=epochz,
        callbacks=[lr_reduction, early_stopping],
        verbose=1
    )

# Evaluate model
loss, accuracy = model.evaluate(test_generator, verbose=False)
y_pred = model.predict(test_generator)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = test_generator.classes

# Metrics
precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred_classes, average='weighted')
mAP = average_precision_score(tf.keras.utils.to_categorical(y_true), y_pred, average='weighted')

# Confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)
cm_percent = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] * 100

# Plot results
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.savefig(f'/app/data/graphs/multi2_{dataset_name}_{epochz}epoch_batch{batch_size}_{model_name}_training_history.png')
plt.close()

plt.figure(figsize=(10, 8))
sns.heatmap(cm_percent, annot=True, fmt='.2f', cmap='Blues')
plt.title('Confusion Matrix (%)')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.savefig(f'/app/data/graphs/multi2_{dataset_name}_{epochz}epoch_batch{batch_size}_{model_name}_confusion_matrix.png')
plt.close()

# Save results
with open('/app/data/results.txt', 'w') as f:
    f.write(f"Test Accuracy: {accuracy:.4f}\n")
    f.write(f"Precision: {precision:.4f}\n")
    f.write(f"Recall: {recall:.4f}\n")
    f.write(f"F1 Score: {f1:.4f}\n")
    f.write(f"mAP: {mAP:.4f}\n")

# Save model
model.save("/app/data/trashnet_model.keras")

print("Training and evaluation complete!")
# Out:
# 2024-10-10 20:39:48.705207: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-10 20:39:48.715338: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-10 20:39:48.726282: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-10 20:39:48.729663: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-10 20:39:48.738243: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Found 2024 images belonging to 6 classes.
# Found 503 images belonging to 6 classes.
# Found 2527 images belonging to 6 classes.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728592790.432417   21585 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728592790.436339   21585 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728592790.436465   21585 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728592790.500264   21585 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728592790.500422   21585 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728592790.500488   21585 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728592790.551385   21585 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728592790.551497   21585 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728592790.551565   21585 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-10 20:39:50.551629: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 155 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1050 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1
# Epoch 1/30
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728592793.358570   21693 service.cc:146] XLA service 0x7a6b44010a60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1728592793.358632   21693 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce GTX 1050 Ti, Compute Capability 6.1
# 2024-10-10 20:39:53.434905: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-10-10 20:39:53.841458: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8906
# 2024-10-10 20:39:53.964208: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 29.00MiB (30408704 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:53.964267: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 26.10MiB (27367936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:53.964294: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.49MiB (24631296 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:53.964318: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 21.14MiB (22168320 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:53.964342: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 19.03MiB (19951616 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:53.964348: W external/local_tsl/tsl/framework/bfc_allocator.cc:363] Garbage collection: deallocate free memory regions (i.e., allocations) so that we can re-allocate a larger region to avoid OOM due to memory fragmentation. If you see this message frequently, you are running near the threshold of the available device memory and re-allocation may incur great performance overhead. You may try smaller batch sizes to observe the performance impact. Set TF_ENABLE_GPU_GARBAGE_COLLECTION=false if you'd like to disable this feature.
# 2024-10-10 20:39:53.966225: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 45.00MiB (47185920 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:53.966253: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 40.50MiB (42467328 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:53.966276: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 36.45MiB (38220800 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:53.966305: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 32.80MiB (34398720 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:53.966333: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 29.52MiB (30958848 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:53.966366: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 26.57MiB (27863040 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:53.966397: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.92MiB (25076736 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:53.966428: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 21.52MiB (22569216 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.090023: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.090066: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.090090: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.090113: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.090135: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.090140: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 16.29MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-10-10 20:39:54.090176: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.090200: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.090221: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.090246: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.090271: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.090274: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 16.29MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-10-10 20:39:54.097773: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.097813: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.097836: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.097858: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.097863: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 17.76MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-10-10 20:39:54.097898: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.097926: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.097948: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.097969: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.097972: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 17.76MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-10-10 20:39:54.097999: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.098029: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.098058: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.098084: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.098110: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.098113: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 16.29MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-10-10 20:39:54.098149: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.098171: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.098201: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.098229: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.098253: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.098256: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 16.29MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-10-10 20:39:54.098294: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.098318: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.098346: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.098374: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.098378: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 16.91MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-10-10 20:39:54.146406: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.146456: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.146479: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.146501: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.146522: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.146528: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 16.04MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-10-10 20:39:54.146563: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.146591: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.146613: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.146635: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.146664: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.146669: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 16.04MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-10-10 20:39:54.146704: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.146730: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.146754: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.146779: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.146806: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.146809: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 16.04MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-10-10 20:39:54.146842: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.146869: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.146891: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.146917: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.146943: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.151341: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.151372: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.151399: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.151425: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.151460: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.151482: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.151507: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.151532: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.165100: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.165140: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.165165: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.165187: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.165214: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.165250: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.165279: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.165307: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.165329: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.165350: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.165385: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.165410: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.165434: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.165458: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.165482: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.165515: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.165537: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.165558: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.165579: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.165603: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.165630: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.165653: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.165678: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.165707: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.165730: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.170457: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.170489: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.170514: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.170539: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.170562: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.170598: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.170622: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.170647: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.170674: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.170697: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.177758: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.177792: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.177815: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.177838: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.177860: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.177900: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.177928: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.177959: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.177986: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.178015: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.178051: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.178077: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.178104: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.178130: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.178157: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.178194: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.178221: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.178244: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.178265: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.178287: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.178317: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.178340: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.178368: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.178392: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.178413: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.178440: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.178462: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.178483: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.178503: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.178526: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.178553: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.178576: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.178597: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.178620: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.178642: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.178668: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.178690: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.199314: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.199357: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.199378: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.199399: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.199421: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.203799: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.203825: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.203847: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.203869: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.203891: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.203921: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.203943: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.203965: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.203986: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204007: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204034: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204055: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204076: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204098: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204119: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204147: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204177: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204207: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204233: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204258: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204289: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204315: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204339: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204362: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204385: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204414: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204438: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204462: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204487: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204511: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204541: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204566: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204590: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204614: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204637: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204665: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204689: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204713: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204737: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204761: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204790: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204814: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204837: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204861: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204886: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204915: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204939: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204962: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.204987: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.205010: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:39:54.205040: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# ...
# 2024-10-10 20:40:03.025479: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.025509: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.025540: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.025567: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.076169: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.076218: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.076244: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.076266: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.076288: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.076321: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.076346: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.076370: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.076392: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.076413: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.123046: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.123088: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.123111: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.123134: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.123159: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.123193: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.123222: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.123244: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.123266: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.123298: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.123336: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.123367: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.123396: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.123423: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.123447: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.123482: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.123510: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.123532: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.123560: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.123590: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.123621: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 25.63MiB (26873600 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.123646: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 23.07MiB (24186368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.123670: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 20.76MiB (21767936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.123695: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 18.68MiB (19591168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-10-10 20:40:03.123718: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 16.82MiB (17632256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# An error occurred during training: Graph execution error:
#
# Detected at node StatefulPartitionedCall defined at (most recent call last):
#   File "/usr/lib/python3.11/runpy.py", line 198, in _run_module_as_main
#
#   File "/usr/lib/python3.11/runpy.py", line 88, in _run_code
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel_launcher.py", line 18, in <module>
#
#   File "/usr/local/lib/python3.11/dist-packages/traitlets/config/application.py", line 1075, in launch_instance
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelapp.py", line 739, in start
#
#   File "/usr/local/lib/python3.11/dist-packages/tornado/platform/asyncio.py", line 205, in start
#
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 604, in run_forever
#
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1909, in _run_once
#
#   File "/usr/lib/python3.11/asyncio/events.py", line 80, in _run
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 534, in process_one
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 362, in execute_request
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 778, in execute_request
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 449, in do_execute
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/zmqshell.py", line 549, in run_cell
#
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#
#   File "/tmp/ipykernel_21585/2640735874.py", line 86, in <module>
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py", line 343, in fit
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py", line 429, in evaluate
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py", line 165, in one_step_on_iterator
#
# Failed to get module function:CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 	 [[{{node StatefulPartitionedCall}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_one_step_on_iterator_13273]
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[1], line 86
#      85 try:
# ---> 86     history = model.fit(
#      87         train_generator,
#      88         steps_per_epoch=train_generator.samples // batch_size,
#      89         validation_data=validation_generator,
#      90         validation_steps=validation_generator.samples // batch_size,
#      91         epochs=epochz,
#      92         callbacks=[lr_reduction, early_stopping],
#      93         verbose=1
#      94     )
#      95 except Exception as e:
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node StatefulPartitionedCall defined at (most recent call last):
#   File "/usr/lib/python3.11/runpy.py", line 198, in _run_module_as_main
#
#   File "/usr/lib/python3.11/runpy.py", line 88, in _run_code
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel_launcher.py", line 18, in <module>
#
#   File "/usr/local/lib/python3.11/dist-packages/traitlets/config/application.py", line 1075, in launch_instance
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelapp.py", line 739, in start
#
#   File "/usr/local/lib/python3.11/dist-packages/tornado/platform/asyncio.py", line 205, in start
#
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 604, in run_forever
#
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1909, in _run_once
#
#   File "/usr/lib/python3.11/asyncio/events.py", line 80, in _run
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 534, in process_one
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 362, in execute_request
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 778, in execute_request
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 449, in do_execute
#
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/zmqshell.py", line 549, in run_cell
#
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#
#   File "/tmp/ipykernel_21585/2640735874.py", line 86, in <module>
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py", line 343, in fit
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py", line 429, in evaluate
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py", line 165, in one_step_on_iterator
#
# Failed to get module function:CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 	 [[{{node StatefulPartitionedCall}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_one_step_on_iterator_13273]
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 100
#      98 tf.keras.backend.clear_session()
#      99 model = create_model()
# --> 100 model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
#     102 # Try training again
#     103 history = model.fit(
#     104     train_generator,
#     105     steps_per_epoch=train_generator.samples // batch_size,
#    (...)
#     110     verbose=1
#     111 )
#
# AttributeError: 'tuple' object has no attribute 'compile'
