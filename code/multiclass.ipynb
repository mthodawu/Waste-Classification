# %%
# %pip install scikit-learn
# %pip install tensorflow
# %pip install seaborn matplotlib pandas

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import os
from tensorflow.keras.backend import clear_session
from sklearn.model_selection import train_test_split
import shutil
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Dense, Flatten
from tensorflow.keras.models import load_model
from tensorflow.keras import mixed_precision
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import precision_recall_fscore_support, confusion_matrix, average_precision_score
from tensorflow.keras.optimizers import SGD
# Enable mixed precision training
mixed_precision.set_global_policy('mixed_float16')

import warnings
warnings.filterwarnings('ignore')

clear_session()  # This frees the GPU memory, peventing training deadlock

# Function to create directories
def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)
        
setz = ['metal','glass', 'trash', 'cardboard', 'paper', 'plastic']

# for setClass in [setz[2]]: #setz:
# clear_session()
global classez
classez = setz #[setClass, 'other']
# data path
global dataset_path
# dataset_path = f'/app/data/Datasets/augmented_{classez[0]}_and_{classez[1]}'  # <- docker file path      # "G:\My Drive\Datasets\ "
dataset_path = f'/app/data/Datasets/Trashnet-resized'  # <- docker file path      # "G:\My Drive\Datasets\ "

tar = (160, 160)#(224, 224)
batch = 1 # 16
#Split the dataset
# Create an ImageDataGenerator for each subset
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)  # 20% for validation

# Training data generator
train_generator = datagen.flow_from_directory(
    dataset_path,
    target_size=tar,
    batch_size=batch,
    class_mode='categorical',
    subset='training')  # Set as training data

# Validation data generator
validation_generator = datagen.flow_from_directory(
    dataset_path,
    target_size=tar,
    batch_size=batch,
    class_mode='categorical',
    subset='validation')  # Set as validation data

# Create a separate ImageDataGenerator for test data
test_datagen = ImageDataGenerator(rescale=1./255)

# Test data generator
test_generator = test_datagen.flow_from_directory(
    dataset_path,
    target_size=tar,
    batch_size=batch,
    class_mode='categorical')  # No subset for testing



# Paths to save splits
base_dir = f'{dataset_path}-split'  # "G:\My Drive\Datasets\Trashnet-resized-split"
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')

create_dir(base_dir)
create_dir(train_dir)
create_dir(val_dir)
create_dir(test_dir)

for class_name in classez: #, 'cardboard', 'metal', 'paper', 'plastic', 'trash']:
    # Create class directories
    create_dir(os.path.join(train_dir, class_name))
    create_dir(os.path.join(val_dir, class_name))
    create_dir(os.path.join(test_dir, class_name))

    # List all files in the class directory
    class_files = os.listdir(os.path.join(dataset_path, class_name))
    train_files, test_files = train_test_split(class_files, test_size=0.2, random_state=42)  # 20% for testing
    train_files, val_files = train_test_split(train_files, test_size=0.25, random_state=42)  # 20% of remaining for validation (0.25 * 0.8 = 0.2)

    # Copy files to respective directories
    for file in train_files:
        shutil.copy(os.path.join(dataset_path, class_name, file), os.path.join(train_dir, class_name, file))

    for file in val_files:
        shutil.copy(os.path.join(dataset_path, class_name, file), os.path.join(val_dir, class_name, file))

    for file in test_files:
        shutil.copy(os.path.join(dataset_path, class_name, file), os.path.join(test_dir, class_name, file))
    
train_generator = datagen.flow_from_directory(
train_dir,
target_size=tar,
batch_size=batch,
class_mode='categorical'
# ,color_mode='grayscale'
)

validation_generator = datagen.flow_from_directory(
    val_dir,
    target_size=tar,
    batch_size=batch,
    class_mode='categorical'
    # ,color_mode='grayscale'
    )

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=tar,
    batch_size=batch,
    class_mode='categorical'
    # ,color_mode='grayscale'
    )

img_shape = (160, 160, 3) #(224,224,3)
img_size = tar
batch_size = batch #16 #32
num_classes = 6
epochz = 30 # 100
# log_file = '/app/data/code/accuracy_logMulti_1.csv'

# DenseNet201 # MobileNetV3 # EfficientNetB0

base_model = tf.keras.applications.DenseNet121(input_shape=img_shape,
                                            include_top=False,
                                            weights='imagenet')

model_name = base_model.name #'EfficientNetB0' # 'DenseNet201' # 'MobileNetV2'
# print(model_name)
log_file = f'/app/data/code/multi_no_aug_{model_name}_log_{epochz}epochs.csv'    # no_aug_

base_model.trainable = False
# for layer in base_model.layers[-3:]:
#     layer.trainable = True
    
class AccuracyLogger(Callback):
    def __init__(self,   log_file, model_name, img_shape, batch_size, num_classes):
        super().__init__()
        self.log_file = log_file
        self.model_name = model_name
        self.img_shape = img_shape
        self.batch_size = batch_size
        self.num_classes = num_classes
        
        # self.summary = summary

        # Write model and dataset information at the beginning of the log file
        with open(self.log_file, 'a') as f:
            f.write(f"\nModel: {self.model_name}\n")
            # f.write(f"Model summary:{self.summary}\n")
            f.write(f"Image shape: {self.img_shape}\n")
            f.write(f"Batch size: {self.batch_size}\n")
            f.write(f"Dataset: {dataset_path}\n")
            f.write(f"Number of classes: {self.num_classes}\n\n")
            # f.write('Epoch,Accuracy,Validation Accuracy, Loss, Validation Loss\n')
            f.flush()

    # def on_epoch_end(self, epoch, logs=None):
    #     logs = logs or {}
    #     accuracy = logs.get('accuracy')
    #     val_accuracy = logs.get('val_accuracy')
    #     loss = logs.get('loss')
    #     val_loss = logs.get('val_loss')

    #     # Write the epoch, accuracy, and validation accuracy to the log file
    #     with open(self.log_file, 'a') as f:
    #         f.write(f"{epoch + 1},{accuracy},{val_accuracy},{loss},{val_loss}\n")
    #         f.flush()

model = tf.keras.Sequential([base_model,
                             tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=img_shape),
                            #  tf.keras.layers.Flatten(),
                             tf.keras.layers.GlobalAveragePooling2D(),
                             tf.keras.layers.Dense(64, activation="relu"),
                            # tf.keras.layers.Dropout(0.2),
                            # tf.keras.layers.Dense(num_classes, activation="sigmoid")
                             tf.keras.layers.Dense(num_classes, activation="softmax")
                            ])

lr_reduction = ReduceLROnPlateau(monitor='val_loss', 
                                patience=2, 
                                factor=0.3, #0.5,
                                verbose=1, 
                                min_lr=0.00001) #0.01)

optimizer = SGD(learning_rate=0.00001) 
model.compile(optimizer = optimizer,
            loss = 'categorical_crossentropy',
            metrics = ['accuracy'])


steps_per_epoch=int(len(train_generator)/batch_size)
validation_steps = validation_generator.samples // validation_generator.batch_size


# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    validation_data=validation_generator,
    callbacks=[AccuracyLogger(  log_file, model_name, img_shape, batch_size, num_classes),
                EarlyStopping(patience=5)],
    epochs=epochz,
    verbose=1
)

def plot_graphs(history, batch_size):
    fig, axs = plt.subplots(1, 2, figsize=(12, 5))  # 1 row, 2 columns

    # Plot accuracy
    axs[0].plot(history.history['accuracy'])
    axs[0].plot(history.history['val_accuracy'])
    axs[0].set_title("Model Accuracy")
    axs[0].set_xlabel("Epochs")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(['Train', 'Validation'])

    # Plot loss
    axs[1].plot(history.history['loss'])
    axs[1].plot(history.history['val_loss'])
    axs[1].set_title("Model Loss")
    axs[1].set_xlabel("Epochs")
    axs[1].set_ylabel("Loss")
    axs[1].legend(['Train', 'Validation'])

    plt.tight_layout()  # Adjust layout to make sure plots don't overlap

    # Ensure the save directory exists
    save_dir = '/app/data/graphs/'
    os.makedirs(save_dir, exist_ok=True)

    # Create the filename using the dataset path and batch size
    dataset_name = os.path.basename(dataset_path[18:])  # filter out '/app/data/Datasets/' 
    filename = f"multi_{dataset_name}_{epochz}epoch_batch{batch_size}_{model_name}.png"

    # Save the figure
    save_path = os.path.join(save_dir, filename)
    plt.savefig(save_path)
    print(f"Graph saved at: {save_path}")

    plt.show()

# plot
plot_graphs(history, batch)

# loss, accuracy = model.evaluate(test_generator, verbose=False)
# print("Testing Accuracy:  {:.4f}".format(accuracy))
# with open(log_file, 'a') as f:
#     f.write(f"Testing Accuracy:  {accuracy:.4f}\n")
#     f.flush()

# # save model
# model.save("/app/data/tf_model_multi.keras")
loss, accuracy = model.evaluate(test_generator, verbose=False)
# Predict on test data
y_pred = model.predict(test_generator)

# threshold = 0.5
# y_pred_classes = (y_pred >= threshold).astype(int)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = test_generator.classes

# Calculate precision, recall, and F1 score
precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred_classes, average='weighted')

# Calculate mAP
# Note: This assumes binary classification. For multi-class, you'll need to modify this.
mAP = average_precision_score(tf.keras.utils.to_categorical(y_true), y_pred, average='weighted')

# Create confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)

# Calculate percentages for the confusion matrix
cm_percent = cm.astype('float') / cm.sum() * 100

# Create annotations that combine the raw values and percentages
annot = np.empty_like(cm).astype(str)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        annot[i, j] = f'{cm[i, j]}\n({cm_percent[i, j]:.2f}%)'


# Log the metrics
with open(log_file, 'a') as f:
    f.write(f"Testing Accuracy: {accuracy:.4f}\n")
    f.write(f"Precision: {precision:.4f}\n")
    f.write(f"Recall: {recall:.4f}\n")
    f.write(f"F1 Score: {f1:.4f}\n")
    f.write(f"mAP: {mAP:.4f}\n")
    f.flush()

# Plot and save confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=annot, fmt='', cmap='Blues', xticklabels=classez, yticklabels=classez)
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.savefig(f'/app/data/graphs/{model_name}_multiclass_confusion_matrix.png')
plt.close()

# Print metrics
# print(f"Testing Accuracy: {accuracy:.4f}")
# print(f"Precision: {precision:.4f}")
# print(f"Recall: {recall:.4f}")
# print(f"F1 Score: {f1:.4f}")
# print(f"mAP: {mAP:.4f}")
# print(f"Confusion Matrix saved as '{setClass}_confusion_matrix.png'")

# Save model
model.save(f"/app/data/{model_name}_multi.keras")
print(f"Multiclass model trained and tested successfully!")

print("Training complete!")
# Out:
# 2024-10-10 17:16:08.103533: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-10 17:16:08.113255: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-10 17:16:08.123891: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-10 17:16:08.127146: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-10 17:16:08.135466: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Found 2024 images belonging to 6 classes.
# Found 503 images belonging to 6 classes.
# Found 2527 images belonging to 6 classes.
# Found 1512 images belonging to 6 classes.
# Found 507 images belonging to 6 classes.
# Found 508 images belonging to 6 classes.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728580570.031549   19479 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728580570.037131   19479 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728580570.037299   19479 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728580570.038038   19479 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728580570.038162   19479 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728580570.038259   19479 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728580570.096348   19479 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728580570.096470   19479 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728580570.096548   19479 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-10 17:16:10.096614: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 170 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1050 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728580576.787785   19630 service.cc:146] XLA service 0x7e32600029a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1728580576.787807   19630 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce GTX 1050 Ti, Compute Capability 6.1
# 2024-10-10 17:16:17.030555: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-10-10 17:16:18.241285: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8906
# 2024-10-10 17:16:18.771787: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 51.72MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-10-10 17:16:19.346630: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 153.12MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-10-10 17:16:19.423665: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 51.20MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-10-10 17:16:19.482232: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 187.41MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-10-10 17:16:19.545859: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 221.69MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-10-10 17:16:19.609960: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 255.97MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-10-10 17:16:19.682458: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 290.25MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-10-10 17:16:19.755910: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 324.53MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-10-10 17:16:19.835542: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 358.81MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-10-10 17:16:19.913740: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 393.09MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
#   18/1512 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.3276 - loss: 1.9276
# I0000 00:00:1728580584.637901   19630 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 37s 15ms/step - accuracy: 0.2339 - loss: 1.7915 - val_accuracy: 0.3314 - val_loss: 1.5778
# Epoch 2/30
# 2024-10-10 17:16:47.979677: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-10-10 17:16:47.980001: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 	 [[IteratorGetNext/_2]]
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.3314 - val_loss: 1.5778
# Epoch 3/30
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - accuracy: 0.3442 - loss: 1.5632 - val_accuracy: 0.4320 - val_loss: 1.4359
# Epoch 4/30
# 2024-10-10 17:17:12.021309: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 	 [[IteratorGetNext/_2]]
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.4320 - val_loss: 1.4359
# Epoch 5/30
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.4285 - loss: 1.4236 - val_accuracy: 0.4872 - val_loss: 1.3260
# Epoch 6/30
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.4872 - val_loss: 1.3260
# Epoch 7/30
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - accuracy: 0.5297 - loss: 1.3011 - val_accuracy: 0.5345 - val_loss: 1.2352
# Epoch 8/30
# 2024-10-10 17:18:00.398726: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 	 [[IteratorGetNext/_2]]
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.5345 - val_loss: 1.2352
# Epoch 9/30
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - accuracy: 0.5716 - loss: 1.1923 - val_accuracy: 0.5700 - val_loss: 1.1517
# Epoch 10/30
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.5700 - val_loss: 1.1517
# Epoch 11/30
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - accuracy: 0.5971 - loss: 1.1409 - val_accuracy: 0.6036 - val_loss: 1.0824
# Epoch 12/30
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.6036 - val_loss: 1.0824
# Epoch 13/30
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - accuracy: 0.6453 - loss: 1.0489 - val_accuracy: 0.6489 - val_loss: 1.0240
# Epoch 14/30
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.6489 - val_loss: 1.0240
# Epoch 15/30
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - accuracy: 0.6744 - loss: 0.9887 - val_accuracy: 0.6588 - val_loss: 0.9754
# Epoch 16/30
# 2024-10-10 17:19:36.514584: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 	 [[IteratorGetNext/_2]]
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.6588 - val_loss: 0.9754
# Epoch 17/30
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - accuracy: 0.6996 - loss: 0.9106 - val_accuracy: 0.6686 - val_loss: 0.9385
# Epoch 18/30
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.6686 - val_loss: 0.9385
# Epoch 19/30
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - accuracy: 0.7157 - loss: 0.8488 - val_accuracy: 0.6785 - val_loss: 0.9071
# Epoch 20/30
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.6785 - val_loss: 0.9071
# Epoch 21/30
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - accuracy: 0.7445 - loss: 0.8105 - val_accuracy: 0.6824 - val_loss: 0.8794
# Epoch 22/30
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.6824 - val_loss: 0.8794
# Epoch 23/30
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.7275 - loss: 0.8332 - val_accuracy: 0.6943 - val_loss: 0.8544
# Epoch 24/30
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.6943 - val_loss: 0.8544
# Epoch 25/30
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.7513 - loss: 0.7578 - val_accuracy: 0.7022 - val_loss: 0.8330
# Epoch 26/30
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.7022 - val_loss: 0.8330
# Epoch 27/30
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.7459 - loss: 0.7453 - val_accuracy: 0.7041 - val_loss: 0.8150
# Epoch 28/30
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.7041 - val_loss: 0.8150
# Epoch 29/30
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - accuracy: 0.7717 - loss: 0.7167 - val_accuracy: 0.7061 - val_loss: 0.7977
# Epoch 30/30
# 1512/1512 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.7061 - val_loss: 0.7977
# Graph saved at: /app/data/graphs/multi_Trashnet-resized_30epoch_batch1_densenet121.png
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step
# Multiclass model trained and tested successfully!
# Training complete!
